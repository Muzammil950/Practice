# %% [markdown]
# # PYTHON ~
# ### Python is a high level, general-purpose programming language know for its simple **syntax**, **readability** and large ecosystem of libraries
# It is widely used in:
# Data Science & Machine Learning
#
# Artificial Intelligence
#
# Web Development
#
# Automation & Scripting
#
# Software Development
#
# Cybersecurity
#
# **created by Guido van Rossum**

# %% [markdown]
# ## ⭐Variables
# ### A variable is a name that stores a value in memory.

# %%
name = "Asif"  # name is variable
roll = 123     # roll is variable
male = True    # male is variable

# %% [markdown]
# ### ⭐Variables store different types of data

# %%
x = 5              #Integer
y = 3.14           #Float
name = "Amit"      #String
flag = True        #Boolean
nums = [1, 2, 3]   #List

# %% [markdown]
# ### ⭐Interactive Mode
#
# 1. You write and run Python commands one line at a time.
#
# 2. Best for testing small pieces of code quickly.
#
# 3. Runs in the Python shell/IDLE terminal, or Jupyter Notebook.
#
# 4. Output appears immediately after you press Enter.

# %%
2 + 3
# Out:
# 5

# %%
print("hello")
# Out:
# hello

# %% [markdown]
# ### ⭐Script Mode
#
# 1. You write Python code inside a .py file.
#
# 2. Then run the entire file at once.
#
# 3. Best for writing full programs and projects.
#
# 4. Runs from VS Code, PyCharm, or using:

# %%
a = 10
b = 20
print(a + b)
# Out:
# 30

# %% [markdown]
# ## ⭐Comments in Python
#
# #### Comments are notes written in code to explain what the code does.

# %% [markdown]
# ### ⭐Single-line comment

# %%
x = 10  # This comment explains the variable

# %% [markdown]
# ### ⭐Multi-line Comment

# %%
"""
This is a multi-line comment.
It can span multiple lines.
"""
print("Hello")
# Out:
# Hello

# %% [markdown]
# ## ⭐Indentation in Python
#
# ### Indentation means adding spaces or tabs at the beginning of a line to show block structure.
# ### It defines blocks of code (loops, functions, conditions, classes).

# %%
if 5 > 3:
    print("Yes")
# Out:
# Yes

# %% [markdown]
# ## ⭐Python Character sets
# | **Category**          | **What It Includes**                     | **Simple Example**               |
# | --------------------- | ---------------------------------------- | -------------------------------- |
# | **Letters**           | A–Z, a–z                                 | `name = "pythonaliya"`                   |
# | **Digits**            | 0–9                                      | `age = 21`                       |
# | **Symbols**           | +, -, *, /, =, (), {}, [], ., ,, :, ', " | `x = 10 + 5`                     |
# | **Whitespace**        | Space, Tab (`\t`), Newline (`\n`)        | `"Hello World"`                  |
# | **Escape Characters** | `\n`, `\t`, `\"`, `\'`, `\\`             | `print("Hello\nWorld")`          |
# | **Unicode**           | Emojis, other languages                  | `print("🙂")`, `print("नमस्ते")` |

# %% [markdown]
# ## ⭐Python Operators
# ### Operator = A symbol that performs an action (add, compare, assign, etc.)
# ### 1. Arithmetic Operators
# | Operator | Meaning        | Example   | Result |
# | -------- | -------------- | --------- | ------ |
# | `+`      | Add            | `10 + 5`  | 15     |
# | `-`      | Subtract       | `10 - 5`  | 5      |
# | `*`      | Multiply       | `10 * 5`  | 50     |
# | `/`      | Divide         | `10 / 5`  | 2.0    |
# | `%`      | Remainder      | `10 % 3`  | 1      |
# | `**`     | Power          | `2 ** 3`  | 8      |
# | `//`     | Floor division | `10 // 3` | 3      |

# %% [markdown]
# ### 2. Assignment Operators
# | Operator | Meaning           | Example                        |
# | -------- | ----------------- | ------------------------------ |
# | `=`      | Assign value      | `x = 10`                       |
# | `+=`     | Add & assign      | `x += 5` (same as `x = x + 5`) |
# | `-=`     | Subtract & assign | `x -= 5`                       |
# | `*=`     | Multiply & assign | `x *= 5`                       |
# | `/=`     | Divide & assign   | `x /= 5`                       |

# %% [markdown]
# ### 3. Comparison Operators
# | Operator | Meaning          | Example         |
# | -------- | ---------------- | --------------- |
# | `==`     | Equal to         | `5 == 5` → True |
# | `!=`     | Not equal        | `5 != 3` → True |
# | `>`      | Greater than     | `5 > 3`         |
# | `<`      | Less than        | `5 < 3`         |
# | `>=`     | Greater or equal | `5 >= 5`        |
# | `<=`     | Less or equal    | `3 <= 5`        |

# %% [markdown]
# ### 4. Logical Operators
# | Operator | Meaning              | Example            |
# | -------- | -------------------- | ------------------ |
# | `and`    | Both conditions true | `5 > 2 and 3 < 5`  |
# | `or`     | One condition true   | `5 > 2 or 3 > 10`  |
# | `not`    | Reverse result       | `not True` → False |

# %% [markdown]
# ### 5. Membership Operators
# | Operator | Meaning              | Example              |
# | -------- | -------------------- | -------------------- |
# | `in`     | Value present or not | `"a" in "apple"`     |
# | `not in` | Value not present    | `"b" not in "apple"` |

# %% [markdown]
# ### 6. Identity Operators
# | Operator | Meaning                 | Example      |
# | -------- | ----------------------- | ------------ |
# | `is`     | Both values same object | `x is y`     |
# | `is not` | Not same object         | `x is not y` |

# %% [markdown]
# ### 7. Bitwise Operators (Work on bits)
# | Operator | Meaning     |    |
# | -------- | ----------- | -- |
# | `&`      | AND         |    |
# | `        | `           | OR |
# | `^`      | XOR         |    |
# | `~`      | NOT         |    |
# | `<<`     | Left shift  |    |
# | `>>`     | Right shift |    |

# %% [markdown]
# ## ⭐Python Keywords
#
# 1. Keywords are special words in Python.
# 2. You cannot use them as variable names.
# 3. Python uses them for commands and rules.
# | **Column 1**               | **Column 2**             | **Column 3**                       |
# | -------------------------- | ------------------------ | ---------------------------------- |
# | and – both conditions true | return – give back value | True – boolean true                |
# | or – one condition true    | class – create class     | False – boolean false              |
# | not – reverse result       | try – test code          | None – no value                    |
# | if – condition             | except – handle error    | in – check inside                  |
# | elif – extra condition     | finally – always runs    | is – identity check                |
# | else – otherwise           | import – bring module    | yield – generator return           |
# | for – loop                 | from – import part       | global – global variable           |
# | while – loop until false   | as – rename              | nonlocal – outer function variable |
# | break – stop loop          | pass – do nothing        | lambda – small function            |
# | continue – skip step       | with – resource handling | raise – throw error                |
# | def – create function      | assert – debug check     | del – delete                       |

# %% [markdown]
# ## ⭐Python Data Types
# Data Types = The type of value stored in a variable.
# | **Data Type**         | **Meaning (Simple English)**         | **Example**        |
# | --------------------- | ------------------------------------ | ------------------ |
# | **int**               | Whole numbers                        | `10`, `-5`         |
# | **float**             | Decimal numbers                      | `3.14`, `2.0`      |
# | **string (str)**      | Text or characters                   | `"Hello"`, `"123"` |
# | **boolean (bool)**    | True or False values                 | `True`, `False`    |
# | **list**              | Ordered, changeable, multiple values | `[1, 2, 3]`        |
# | **tuple**             | Ordered, unchangeable values         | `(1, 2, 3)`        |
# | **set**               | Unordered, unique values             | `{1, 2, 3}`        |
# | **dictionary (dict)** | Key–value pairs                      | `{"name": "Ali"}`  |
# | **complex**           | Complex numbers                      | `3 + 5j`           |
# | **NoneType**          | No value / empty                     | `None`             |
